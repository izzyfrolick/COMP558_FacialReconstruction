# %%
# %pip install --upgrade pip
# %pip install absl-py==0.15.0
# %pip install addict==2.4.0
# %pip install aiohappyeyeballs==2.4.0
# %pip install aiohttp==3.10.5
# %pip install aiosignal==1.3.1
# %pip install appnope==0.1.4
# %pip install asttokens==2.4.1
# %pip install astunparse==1.6.3
# %pip install async-timeout==4.0.3
# %pip install attrs==24.2.0
# %pip install blinker==1.8.2
# %pip install Brotli==1.1.0
# %pip install cached-property==1.5.2
# %pip install cachetools==5.5.0
# %pip install certifi==2024.8.30
# %pip install cffi==1.17.1
# %pip install charset-normalizer==3.3.2
# %pip install click==8.1.7
# %pip install comm==0.2.2
# %pip install ConfigArgParse==1.7
# %pip install contourpy==1.3.0
# %pip install cryptography==39.0.0
# %pip install cycler==0.12.1
# %pip install dash==2.18.2
# %pip install dash-core-components==2.0.0
# %pip install dash-html-components==2.0.0
# %pip install dash-table==5.0.0
# %pip install debugpy==1.8.9
# %pip install decorator==5.1.1
# %pip install exceptiongroup==1.2.2
# %pip install executing==2.1.0
# %pip install fastjsonschema==2.21.0
# %pip install filelock==3.13.1
# %pip install Flask==3.0.3
# %pip install flatbuffers==1.12
# %pip install fonttools==4.55.0
# %pip install frozenlist==1.4.1
# %pip install gast==0.4.0
# %pip install gmpy2==2.1.2
# %pip install google-auth==2.35.0
# %pip install google-auth-oauthlib==0.4.6
# %pip install google-pasta==0.2.0
# %pip install grpcio==1.39.0
# %pip install h2==4.1.0
# %pip install h5py==3.1.0
# %pip install hpack==4.0.0
# %pip install hyperframe==6.0.1
# %pip install idna==3.10
# %pip install importlib_metadata==8.5.0
# %pip install importlib_resources==6.4.5
# %pip install ipykernel==6.29.5
# %pip install ipython==8.18.1
# %pip install itsdangerous==2.2.0
# %pip install jedi==0.19.2
# %pip install Jinja2==3.1.4
# %pip install joblib==1.4.2
# %pip install jsonschema==4.23.0
# %pip install jsonschema-specifications==2024.10.1
# %pip install jupyter_client==8.6.3
# %pip install jupyter_core==5.7.2
# %pip install keras==2.6.0
# %pip install Keras-Preprocessing==1.1.2
# %pip install kiwisolver==1.4.7
# %pip install Markdown==3.6
# %pip install MarkupSafe==2.1.5
# %pip install matplotlib==3.9.3
# %pip install matplotlib-inline==0.1.7
# %pip install mpmath==1.3.0
# %pip install multidict==6.1.0
# %pip install nbformat==5.10.4
# %pip install nest_asyncio==1.6.0
# %pip install networkx==3.2.1
# %pip install numpy==1.24.4
# %pip install oauthlib==3.2.2
# %pip install open3d==0.18.0
# %pip install opencv-python==4.10.0.84
# %pip install opt-einsum==3.3.0
# %pip install packaging==24.1
# %pip install pandas==2.2.3
# %pip install parso==0.8.4
# %pip install pexpect==4.9.0
# %pip install pickleshare==0.7.5
# %pip install pillow==10.4.0
# %pip install pip==24.2
# %pip install platformdirs==4.3.6
# %pip install plotly==5.24.1
# %pip install pooch==1.8.2
# %pip install prompt_toolkit==3.0.48
# %pip install protobuf==3.16.0
# %pip install psutil==6.1.0
# %pip install ptyprocess==0.7.0
# %pip install pure_eval==0.2.3
# %pip install pyasn1==0.6.1
# %pip install pyasn1_modules==0.4.1
# %pip install pycparser==2.22
# %pip install Pygments==2.18.0
# %pip install PyJWT==2.9.0
# %pip install pyOpenSSL==23.2.0
# %pip install pyparsing==3.2.0
# %pip install pyquaternion==0.9.9
# %pip install PySocks==1.7.1
# %pip install python-dateutil==2.9.0.post0
# %pip install pytz==2024.2
# %pip install pyu2f==0.1.5
# %pip install PyYAML==6.0.1
# %pip install pyzmq==26.2.0
# %pip install referencing==0.35.1
# %pip install requests==2.32.3
# %pip install requests-oauthlib==2.0.0
# %pip install retrying==1.3.4
# %pip install rpds-py==0.21.0
# %pip install rsa==4.9
# %pip install scikit-learn==1.5.2
# %pip install scipy==1.9.1
# %pip install setuptools==74.1.2
# %pip install six==1.15.0
# %pip install stack-data==0.6.2
# %pip install sympy==1.13.2
# %pip install tenacity==9.0.0
# %pip install tensorboard==2.11.2
# %pip install tensorboard-data-server==0.6.1
# %pip install tensorboard-plugin-wit==1.8.1
# %pip install tensorflow==2.6.0
# %pip install tensorflow-estimator==2.6.0
# %pip install termcolor==1.1.0
# %pip install threadpoolctl==3.5.0
# %pip install torch==2.4.1
# %pip install torchaudio==2.4.1
# %pip install torchvision==0.19.1
# %pip install tornado==6.4.2
# %pip install tqdm==4.67.1
# %pip install traitlets==5.14.3
# %pip install typing_extensions==4.12.2
# %pip install tzdata==2024.2
# %pip install urllib3==2.2.3
# %pip install wcwidth==0.2.13
# %pip install Werkzeug==3.0.4
# %pip install wheel==0.44.0
# %pip install wrapt==1.12.1
# %pip install yarl==1.9.4
# %pip install zipp==3.20.2
# %pip install zstandard==0.23.0

# %%
# %ls
# Out:
# CopyElise.code-workspace       point_cloud2.ply
# MostUpdated_Isabel.ipynb       point_cloud_img1.csv
# colour_translated_glasses.npy  point_cloud_img2.csv
# combined_image.jpg             projected_image.png
# depth_translation_glasses.npy  voxel_rgb_diff.ply
# point_cloud1.ply

# %%
import numpy as np
import cv2
from pathlib import Path
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.neighbors import NearestNeighbors
import open3d as o3d
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R
import os
from sklearn.neighbors import NearestNeighbors
from sklearn import cluster

# depth_np = np.load('./depth_translation_glasses.npy')
# colour_np = np.load('./colour_translated_glasses.npy')

depth_np = np.load('/Users/isabelfrolick/Downloads/npy_files/depth_no_movement_glasses_orange.npy')
colour_np = np.load('/Users/isabelfrolick/Downloads/npy_files/colour_no_movement_glasses_orange.npy')

# colour_np = np.load('./colour_translated_glasses.npy')
# depth_np = np.load('/Users/isabelfrolick/Comp558_FinalProject/Comp558_FinalProject/Facial_Reconstruction_Project/outputs/mask6/depth.npy')
# colour_np = np.load('/Users/isabelfrolick/Comp558_FinalProject/Comp558_FinalProject/Facial_Reconstruction_Project/outputs/mask6/colour.npy')

# depth_np = np.load('/Users/isabelfrolick/Downloads/no_movement/depth.npy')
# colour_np = np.load('/Users/isabelfrolick/Downloads/no_movement/colour.npy')
#Complete orioginal: 22, 164
#Naiive redo, mask: 53, 245
#Naive redo, glasses: 13, 274
# colour_img1 = colour_np[53]
# colour_img2 = colour_np[245]
# depth_img1 = depth_np[53]
# depth_img2 = depth_np[245]




colour_img1 = colour_np[31]
colour_img2 = colour_np[193]
depth_img1 = depth_np[31]
depth_img2 = depth_np[193]

# %%
# %pip list

# %%
type(depth_img1)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Step 1: Visualize + Normalize Depth

# %% [markdown]
# ### Step 1a: Visualize Images

# %%
plt.figure(figsize=(5, 5))

plt.subplot(2, 2, 1)
plt.imshow(colour_img1)
plt.title("RGB Non-Occluded")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(depth_img1)
plt.title("Depth Non-Occluded")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(colour_img2)
plt.title("RGB Occluded")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(depth_img2)
plt.title("Depth Occluded")
plt.axis("off")

plt.tight_layout()
print(depth_img2.shape)
# Out:
# (240, 320)

# %% [markdown]
# ##### Visualize as HSV

# %%
hsvImg = cv2.cvtColor(colour_img2, cv2.COLOR_RGB2HSV)
print(hsvImg.shape)
plt.imshow(hsvImg[:,:,1])
# Out:
# (240, 320, 3)

# %% [markdown]
# ##### Try to Brighten / Adjust Contrast

# %%
# alpha = 1.3 # Simple contrast control
# beta = 1    # Simple brightness control
# copy_colourImage2 = np.zeros_like(colour_img2)
# copy_colourImage1 = np.zeros_like(colour_img1)

# for y in range(colour_img2.shape[0]):
#     for x in range(colour_img2.shape[1]):
#         for c in range(colour_img2.shape[2]):
#             copy_colourImage2[y,x,c] = np.clip(alpha*colour_img2[y,x,c] + beta, 0, 255)
#             copy_colourImage1[y,x,c] = np.clip(alpha*colour_img1[y,x,c] + beta, 0, 255)

# plt.subplot(1,4,1)
# plt.imshow(colour_img2)
# plt.subplot(1,4,2)
# plt.imshow(copy_colourImage2)
# plt.subplot(1,4,3)
# plt.imshow(colour_img1)
# plt.subplot(1,4,4)
# plt.imshow(copy_colourImage1)

# %% [markdown]
# ### Step 1b: Normalize + Convolve Depth Images to Remove Data Error

# %%
depth_img1_int16 = depth_img1.astype('uint16')

plt.imshow(depth_img1_int16)

# %%
mask = (depth_img1 >= 800) & (depth_img1 <= 1500)

# Set pixels outside this range to 0
depth_img1[~mask] = 0

# %%
mask = (depth_img2 >= 800) & (depth_img2 <= 1500)

# Set pixels outside this range to 0
depth_img2[~mask] = 0

# %%
plt.imshow(depth_img1)
plt.colorbar()

# %% [markdown]
# ##### Check which pixels are kept

# %%
mean_depth = np.mean(depth_img1)

# Find the number of points outside the range (mean ± 100)
threshold = 300
outside_points = np.sum((depth_img1 < mean_depth - threshold) | (depth_img1 > mean_depth + threshold))

print(f"Mean Depth: {mean_depth}")
print(f"Number of points more than {threshold} outside of the average depth: {outside_points}")

threshold = 100

# Create a mask for points outside the range (mean ± 100)
mask = (depth_img1 < mean_depth - threshold) | (depth_img1 > mean_depth + threshold)

# Plot the original depth image
plt.figure(figsize=(16, 8))

plt.subplot(1, 2, 1)
plt.imshow(depth_img1, cmap='gray')
plt.title("Original Depth Image")
plt.axis("off")

# Highlight the points outside the range in a binary image
highlighted_image = np.zeros_like(depth_img1)  # Create a blank image
highlighted_image[mask] = 255  # Mark the outliers in white

plt.subplot(1, 2, 2)
plt.imshow(highlighted_image, cmap='gray')
plt.title(f"Points Outside Mean ± {threshold}")
plt.axis("off")
plt.show()
# Out:
# Mean Depth: 128.07623697916668
# Number of points more than 300 outside of the average depth: 7022

# %% [markdown]
# ## Step 2: Convert the Depth Images to Point Clouds

# %% [markdown]
# #### Functions for Point Clouds

# %%
def create_point_cloud_from_images(color_img, depth_img, intrinsics):
    """
    Create a point cloud from a color image and a depth image using the camera intrinsics.
    
    Args:
        color_img (np.ndarray): RGB image (H, W, 3).
        depth_img (np.ndarray): Depth image (H, W) in meters.
        intrinsics (dict): Camera intrinsics with keys: fx, fy, cx, cy.
        
    Returns:
        open3d.geometry.PointCloud: The generated point cloud.
    """
    h, w = depth_img.shape
    max_depth = 2.0
    # Generate pixel grid
    i, j = np.meshgrid(np.arange(w), np.arange(h))  # Pixel indices
    z = depth_img.flatten()  # Depth values
    x = -(j.flatten() - intrinsics['cx']) * z / intrinsics['fx']
    y = (i.flatten() - intrinsics['cy']) * z / intrinsics['fy']

    # Filter out invalid points (where depth is 0)
    valid = z > 0  & (z < max_depth)
    points = np.vstack((x[valid], y[valid], z[valid])).T

    # Map colors to points
    colors = color_img.reshape(-1, 3)[valid] / 255.0  # Normalize RGB to [0, 1]

    # Create Open3D PointCloud object

    num_points = min(50000, points.shape[0])  # Limit to 100,000 points
    indices = np.random.choice(points.shape[0], num_points, replace=False)
    sampled_points = points[indices]
    sampled_colors = colors[indices]

    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(sampled_points)
    point_cloud.colors = o3d.utility.Vector3dVector(sampled_colors)

    return point_cloud

# %%
# Visualize the point clouds

# Function to handle the 'Q' key press for closing the window
def close_window(vis):
    print("Closing the window")
    vis.destroy_window()

def visualizePointCloud(pcd):
    vis = o3d.visualization.VisualizerWithKeyCallback()
    vis.create_window()

    # Add the point cloud to the visualizer
    vis.add_geometry(pcd)
    # Create and add the coordinate axes to the visualizer
    axis = o3d.geometry.TriangleMesh.create_coordinate_frame(size=300, origin=[0, 0, 0])
    vis.add_geometry(axis)

    
    # Bind the 'Q' key to close the window
    vis.register_key_callback(ord('Q'), close_window)

    # Start the visualization
    vis.run()

# %% [markdown]
# #### Create Point Clouds + Visualize for Original Depth Images

# %%
# Intrinsic parameters of your camera
intrinsics = {
    'fx': 583.2829786373293,  # Focal length in x (example)
    'fy': 579.4112549695428,  # Focal length in y (example)
    'cx': 320.0 /2,  # Principal point x (example)
    'cy': 240.0/2,  # Principal point y (example)
}


# Create point clouds
pcd1 = create_point_cloud_from_images(colour_img1, depth_img1, intrinsics)
pcd2 = create_point_cloud_from_images(colour_img2, depth_img2, intrinsics)

visualizePointCloud(pcd1)
visualizePointCloud(pcd2)
# Save point clouds as .ply files (or any other format like .pcd, .xyz)
o3d.io.write_point_cloud("point_cloud1.ply", pcd1)
# o3d.io.write_point_cloud("point_cloud2.ply", pcd2)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# True

# %% [markdown]
# ##### TODO: Try to clump the pixels to fill in the point clouds?

# %% [markdown]
# ## Step 3: Get Keypoints and Corresponding Features between Images
#
# There are a few ways to do this: we can either do it in 2D using the depth images, which is computationally faster, or in 3D using the Point Clouds. We have tried both ways below.

# %% [markdown]
# ### Step 3a: Get Corresponding Features in 2D

# %% [markdown]
# Extract keypoint coordinates and matches them

# %%
def getCorrespondingKeypoint2D(depth_img1, depth_img2, tolerance):
    # Convert depth images to uint8 for visualization and keypoint detection
    depth_img1_vis = cv2.normalize(depth_img1, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_img2_vis = cv2.normalize(depth_img2, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

    # Detect keypoints using ORB
    orb = cv2.ORB_create()
    kp1 = orb.detect(depth_img1_vis, None)
    kp2 = orb.detect(depth_img2_vis, None)

    # Extract coordinates of keypoints
    coords1 = np.array([kp.pt for kp in kp1])  
    coords2 = np.array([kp.pt for kp in kp2])  
    # Compare coordinates to find matches
    matches = []
    distances = []
    for i, pt1 in enumerate(coords1):
        for j, pt2 in enumerate(coords2):
            if np.allclose(pt1, pt2, atol=tolerance):  # small tolerance
                matches.append((pt1, pt2))  
                distance = np.linalg.norm(pt1 - pt2)
                distances.append(distance)
    
   
       # Store matches as (x, y, depth) tuples
    img1_matches = []
    img2_matches = []
    for pt1, pt2 in matches:
        x1, y1 = int(pt1[0]), int(pt1[1])
        x2, y2 = int(pt2[0]), int(pt2[1])
        
        depth1 = depth_img1[y1, x1]  # Get depth value from original depth image
        depth2 = depth_img2[y2, x2]  # Get depth value from original depth image
        
        img1_matches.append((x1, y1, depth1))
        img2_matches.append((x2, y2, depth2))
    return img1_matches, img2_matches, distances

def visualizeKeypoints(depth_img1, depth_img2, coords1, coords2):
    depth_img1_vis = cv2.normalize(depth_img1, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_img2_vis = cv2.normalize(depth_img2, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

        # Plot the images with matching keypoints
    plt.figure(figsize=(10, 5))
    colours = plt.cm.jet(np.linspace(0, 1, len(coords1)))    
    # Plot depth_img1 with matching keypoints
    plt.subplot(1, 2, 1)
    plt.imshow(depth_img1_vis, cmap='gray')
    if len(coords1) > 0:
        for i, (x, y, _) in enumerate(coords1):
            plt.plot(x, y, 'o', colours[i])  # Plot keypoints in red
    plt.title("Keypoints on Depth Image 1")
    plt.axis('off')

    # Plot depth_img2 with matching keypoints
    plt.subplot(1, 2, 2)
    plt.imshow(depth_img2_vis, cmap='gray')
    if len(coords2) > 0:
        for i, (x, y, _) in enumerate(coords2):
            plt.plot(x, y, 'o', colours[i])  # Plot keypoints in red
    plt.title("Matching Keypoints on Depth Image 2")
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
def matchingDepthFeatures(depth_img1, depth_img2):
    #Define window size for local region comparison (e.g., 5x5)
    window_size = 5
    half_window = window_size // 2

    # Initialize list for corresponding keypoints
    matches = []

    # Loop through each pixel in depth_img1
    for y in range(half_window, depth_img1.shape[0] - half_window):
        for x in range(half_window, depth_img1.shape[1] - half_window):
            
            # Extract depth value of the current pixel in image 1
            depth_value1 = depth_img1[y, x]
            
            # Define the search window in both images
            window1 = depth_img1[y - half_window : y + half_window + 1, x - half_window : x + half_window + 1]
            window2 = depth_img2[y - half_window : y + half_window + 1, x - half_window : x + half_window + 1]
            
            # Compute the similarity measure (e.g., Mean Squared Error) between the windows
            mse = np.sum((window1 - window2) ** 2)
            
            # Set a threshold for matching windows (you may need to adjust this threshold)
            if mse < 100:  # Example threshold for similarity, tune as necessary
                matches.append(((x, y), mse))

    # Sort matches by similarity score (lower MSE means more similar)
    matches = sorted(matches, key=lambda match: match[1])
    depth_img1_vis = cv2.normalize(depth_img1, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_img2_vis = cv2.normalize(depth_img2, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

    # Plot the results
    img_matches = cv2.drawKeypoints(depth_img1_vis, [cv2.KeyPoint(m[0][0], m[0][1], 1) for m in matches], None, color=(0, 255, 0))

    plt.imshow(img_matches, cmap='gray')
    plt.title("Matched Keypoints Between Depth Images")
    plt.show()

    # Optionally, you can visualize matches as lines connecting corresponding points
    for match in matches[:10]:  # Display top 10 matches
        pt1 = match[0]  # Coordinates from depth_img1
        pt2 = match[0]  # Coordinates from depth_img2
        plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'ro-')  # Draw red lines between matching points
    plt.imshow(depth_img1, cmap='gray')
    plt.title("Matched Points Visualization")
    plt.show()

# %% [markdown]
# #### Older Methods for Keypoints

# %%
# #Based on mins and maxs of depth image
# # min_depth = 1380
# # max_depth = 1700
# min_depth = 1000
# max_depth = 1400

# # Mask the depth image
# depth_mask1 = (depth_img1 >= min_depth) & (depth_img1 <= max_depth)

# # Create a canvas with the same size as the depth image (black by default)
# image1_cropped = np.zeros_like(colour_img1)

# # Loop through the pixels of the color image and apply the depth mask
# for y in range(colour_img1.shape[0]):
#     for x in range(colour_img1.shape[1]):
#         if depth_mask1[y, x]:  # If depth is within the desired range
#             image1_cropped[y, x] = colour_img1[y, x]  # Copy the color from the original image
#         else:
#             image1_cropped[y, x] = (0, 0, 0)  # Set the pixel to black if outside the range


# depth_img1_mask = np.zeros_like(depth_img1)
# for y in range(depth_img2.shape[0]):
#     for x in range(depth_img2.shape[1]):
#         if depth_mask1[y, x] == 0:  # If depth is within the desired range
#             depth_img1_mask[y, x] = 0  # Copy the color from the original image
#         else:
#             depth_img1_mask[y, x] = depth_img2[y,x] # Set the pixel to black if outside the range




# plt.imshow(image1_cropped)
# #canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)

# %%
# #Based on mins and maxs of depth image
# # min_depth = 1380
# # max_depth = 1700
# min_depth = 1000
# max_depth = 1370

# # Mask the depth image
# depth_mask2 = (depth_img2 >= min_depth) & (depth_img2 <= max_depth)

# # Create a canvas with the same size as the depth image (black by default)
# image2_cropped = np.zeros_like(colour_img2)

# # Loop through the pixels of the color image and apply the depth mask
# for y in range(colour_img2.shape[0]):
#     for x in range(colour_img2.shape[1]):
#         if depth_mask2[y, x]:  # If depth is within the desired range
#             image2_cropped[y, x] = colour_img2[y, x]  # Copy the color from the original image
#         else:
#             image2_cropped[y, x] = (0, 0, 0)  # Set the pixel to black if outside the range


# depth_img2_mask = np.zeros_like(depth_img2)
# for y in range(depth_img2.shape[0]):
#     for x in range(depth_img2.shape[1]):
#         if depth_mask2[y, x] == 0:  # If depth is within the desired range
#             depth_img2_mask[y, x] = 0  # Copy the color from the original image
#         else:
#             depth_img2_mask[y, x] = depth_img2[y,x] # Set the pixel to black if outside the range



# plt.imshow(image2_cropped)
# #canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)

# %%
# type(depth_img2_mask)

# %% [markdown]
# ### Step 3b: Feature Detection

# %% [markdown]
# Could always add something to use the SIFT orientation/ scale to find matches (in keypoints)

# %%
def getSIFTFeatures(depth_img1, depth_img2):
    depth_img1 = cv2.normalize(depth_img1, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_img2 = cv2.normalize(depth_img2, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)


    # Initialize the SIFT detector
    sift = cv2.SIFT_create(contrastThreshold=0.006, edgeThreshold=15)

    # Detect keypoints and compute descriptors for both images
    keypoints1, features1 = sift.detectAndCompute(depth_img1, None)
    keypoints2, features2 = sift.detectAndCompute(depth_img2, None)
    print("Features1 shape:", features1.shape)  # Should be a non-empty array
    print("Features2 shape:", features2.shape) 
    # FLANN-based matcher parameters
    # Use FLANN (Fast Library for Approximate Nearest Neighbors) for feature matching
    index_params = dict(algorithm=3, trees=50)  # Use a KDTree index (algorithm=0) with 10 trees
    search_params = dict(checks=200)  # Number of checks to perform (higher is more accurate but slower)

    # Perform feature matching using FLANN-based matcher
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(features1, features2, k=2)  # k=2 means finding the two best matches for each keypoint

    # Apply ratio test (Lowe's ratio test) to filter out weak matches
    good_matches = []
    for m, n in matches:
        if m.distance < 0.6 * n.distance:  # LOWER is more strict
            good_matches.append(m)

    # Draw the good matches on the images
    img_matches = cv2.drawMatches(depth_img1, keypoints1, depth_img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

    # Show the result
    plt.figure(figsize=(10, 5))
    plt.imshow(img_matches)
    plt.axis("off")
    return good_matches, keypoints1, keypoints2, features1, features2
    # cv2.imshow('Keypoint Matches', img_matches)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

# %%
def getORBFeatures(depth_img1, depth_img2):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Normalize depth images to the range [0, 255] and convert to uint8
    depth_img1 = cv2.normalize(depth_img1, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_img2 = cv2.normalize(depth_img2, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

    # Initialize the ORB detector
    orb = cv2.ORB_create(nfeatures=250)  # You can adjust `nfeatures` for more/less keypoints

    # Detect keypoints and compute descriptors for both images
    keypoints1, features1 = orb.detectAndCompute(depth_img1, None)
    keypoints2, features2 = orb.detectAndCompute(depth_img2, None)

    print("Features1 shape:", features1.shape if features1 is not None else "None")
    print("Features2 shape:", features2.shape if features2 is not None else "None")

    # Use BFMatcher with Hamming distance (default for ORB)
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    # Perform feature matching
    matches = bf.match(features1, features2)

    # Sort matches by distance (lower distance is better)
    good_matches = sorted(matches, key=lambda x: x.distance)

    # Draw the good matches on the images
    img_matches = cv2.drawMatches(depth_img1, keypoints1, depth_img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

    # Show the result
    plt.figure(figsize=(10, 5))
    plt.imshow(img_matches)
    plt.title("ORB Feature Matching")
    plt.axis("off")
    plt.show()

    return good_matches, keypoints1, keypoints2, features1, features2

# %% [markdown]
# ##### SIFT Features (not using)

# %%
good_matches, keypoints1, keypoints2, features1, features2= getSIFTFeatures(depth_img1, depth_img2)
len(good_matches) #10
# Out:
# Features1 shape: (34, 128)
# Features2 shape: (18, 128)
# 1

# %% [markdown]
# #### ORB Feature (using!)

# %%
good_matches, keypoints1, keypoints2, features1, features2= getORBFeatures(depth_img1, depth_img2)
len(good_matches) #10

matchingDepthFeatures(depth_img1, depth_img2)
# matching_keypoints_image1, matching_keypoints_image2, distances = getCorrespondingKeypoint2D(depth_img1, depth_img2, tolerance=500)
# avg_mean_distance = np.mean(distances)
# print(avg_mean_distance)
# visualizeKeypoints(depth_img1, depth_img2, matching_keypoints_image1, matching_keypoints_image2)
# len(matching_keypoints_image2)
# Out:
# Features1 shape: (60, 32)
# Features2 shape: (69, 32)

# %%
distances = []
for i, match in enumerate(good_matches):
    print(f'Good Match {i+1}: QueryIdx = {match.queryIdx}, TrainIdx = {match.trainIdx}, Distance = {match.distance}')
    distances.append(match.distance)

mse = np.mean(distances)
print(mse)
good_keypoints1 = [keypoints1[m.queryIdx] for m in good_matches]
good_keypoints2 = [keypoints2[m.trainIdx] for m in good_matches]
# Out:
# Good Match 1: QueryIdx = 34, TrainIdx = 46, Distance = 9.0
# Good Match 2: QueryIdx = 38, TrainIdx = 49, Distance = 10.0
# Good Match 3: QueryIdx = 43, TrainIdx = 56, Distance = 10.0
# Good Match 4: QueryIdx = 52, TrainIdx = 67, Distance = 12.0
# Good Match 5: QueryIdx = 33, TrainIdx = 45, Distance = 14.0
# Good Match 6: QueryIdx = 51, TrainIdx = 51, Distance = 14.0
# Good Match 7: QueryIdx = 15, TrainIdx = 24, Distance = 15.0
# Good Match 8: QueryIdx = 16, TrainIdx = 26, Distance = 15.0
# Good Match 9: QueryIdx = 55, TrainIdx = 64, Distance = 16.0
# Good Match 10: QueryIdx = 56, TrainIdx = 66, Distance = 16.0
# Good Match 11: QueryIdx = 17, TrainIdx = 25, Distance = 17.0
# Good Match 12: QueryIdx = 40, TrainIdx = 61, Distance = 17.0
# Good Match 13: QueryIdx = 44, TrainIdx = 57, Distance = 17.0
# Good Match 14: QueryIdx = 47, TrainIdx = 59, Distance = 17.0
# Good Match 15: QueryIdx = 18, TrainIdx = 28, Distance = 18.0
# Good Match 16: QueryIdx = 8, TrainIdx = 35, Distance = 19.0
# Good Match 17: QueryIdx = 36, TrainIdx = 48, Distance = 20.0
# Good Match 18: QueryIdx = 23, TrainIdx = 12, Distance = 21.0
# Good Match 19: QueryIdx = 42, TrainIdx = 54, Distance = 23.0
# Good Match 20: QueryIdx = 4, TrainIdx = 7, Distance = 25.0
# Good Match 21: QueryIdx = 19, TrainIdx = 9, Distance = 25.0
# Good Match 22: QueryIdx = 29, TrainIdx = 42, Distance = 26.0
# Good Match 23: QueryIdx = 3, TrainIdx = 5, Distance = 43.0
# 18.217391304347824

# %% [markdown]
# ### Step 3c: Compute the transformation between the images

# %% [markdown]
# We can do this a few ways and we're not entirely sure which will work best.
# - Affine transformation 2D
# - Affine transformation in 3D

# %%
kps1 = []
kps2 = []
# for i, kp in enumerate(good_keypoints1):
#     print(f'Keypoint {i}: (x, y) = ({kp.pt[0]}, {kp.pt[1]}), size = {kp.size}, angle = {kp.angle}')
#     kps1.append((kp.pt[0], kp.pt[1]))


kps1 = np.array([kp.pt for kp in good_keypoints1])  
kps2 = np.array([kp.pt for kp in good_keypoints2])

# %% [markdown]
# ##### Affine transformation in 2D
# TODO: Get some metrics to define the Affine transformation against ICP

# %%
# #M, inliers = cv2.findHomography(kps1, kps2, method=cv2.RANSAC) - for projective registration we need rigid

# K = np.eye(3)  # Identity matrix, replace with actual intrinsic matrix if available
# E, mask = cv2.findEssentialMat(kps1, kps2, K)

affineTransform2D = cv2.estimateAffine2D(kps1, kps2, method=cv2.RANSAC)

# %%
#transformed_points = cv2.transform(np.array([kps1]), affineTransform[0])
height, width = depth_img1.shape

# Apply the affine transformation to the image using warpAffine
translated_img_depth = cv2.warpAffine(depth_img1, affineTransform2D[0], (width, height))
translated_img_colour = cv2.warpAffine(colour_img1, affineTransform2D[0], (width, height))

# Display the original and the transformed image side by side
plt.figure(figsize=(10, 5))

# Plot the original image
plt.subplot(1, 2, 1)
plt.imshow(depth_img1, cmap='gray')
plt.title("Original Image")
plt.axis('off')

# Plot the transformed image
plt.subplot(1, 2, 2)
plt.imshow(translated_img_depth, cmap='gray')
plt.title("Translated Image")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Affine Transformation 3D (unused!)

# %%
# # keypoints_3D_img1 = []
# # keypoints_3D_img2 = []

# # for kp1 in kps1:
# #     x1, y1 = int(kp1[0]), int(kp1[1])  # Convert to integer coordinates for image indexing

# #     # Get the depth value at (x, y)
# #     depth_at_point1 = depth_img1[y1, x1]  # Depth value at the keypoint location
    
# #     # # Convert to 3D coordinates using the camera intrinsics
# #     # X1 = (x1 - 160.0) * depth_at_point1 / 583.2829786373293
# #     # Y1 = (y1 - 120.0) * depth_at_point1 / 579.4112549695428
# #     # Z1 = depth_at_point1  # Depth value as Z-coordinate
    
# #     # Store the 3D coordinates (X, Y, Z)
# #     keypoints_3D_img1.append([x1, y1, depth_at_point1])

# # for kp2 in kps2:
# #     x2, y2 = int(kp2[0]), int(kp2[1])  # Convert to integer coordinates for image indexing

# #     # Get the depth value at (x, y)
# #     depth_at_point2 = depth_img2[y2, x2]  # Depth value at the keypoint location
    
# #     # # Convert to 3D coordinates using the camera intrinsics
# #     # X2 = (x2 - 160.0) * depth_at_point2 / 583.2829786373293
# #     # Y2 = (y2 - 120.0) * depth_at_point2 / 579.4112549695428
# #     # Z2 = depth_at_point2  # Depth value as Z-coordinate
    
# #     # Store the 3D coordinates (X, Y, Z)
# #     keypoints_3D_img2.append([x2, y2, depth_at_point2])

# # # Convert the list of 3D points to a numpy array
# # keypoints_3D_img1 = np.array(keypoints_3D_img1)
# # keypoints_3D_img2 = np.array(keypoints_3D_img2)

# # # keypoints_3D_img1_pixel = []
# # # good_keypoints1
# # # print(kps2)

# retVal, affineTransform3D, inliers = cv2.estimateAffine3D(keypoints_3D_img1, keypoints_3D_img2)
# transformed_points = cv2.transform(depth_img1.reshape(-1, 1, 3), affineTransform3D)
# transformed_points.shape
# reshaped_array = transformed_points.reshape(320, 240)

# plt.figure(figsize=(10, 5))

# # Plot the original image
# plt.subplot(1, 2, 1)
# plt.imshow(depth_img1, cmap='gray')
# plt.title("Original Image")
# plt.axis('off')

# # Plot the transformed image
# plt.subplot(1, 2, 2)
# plt.imshow(reshaped_array, cmap='gray')
# plt.title("Translated Image")
# plt.axis('off')

# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### ICP (not working)

# %%
pcd1.points[3949]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pcd1.points[3949]
#
# IndexError:

# %%
# Perform ICP alignment
import copy

transformed_pcd1 = copy.deepcopy(pcd1)

threshold = 80  # Distance threshold
trans_init = np.eye(4)  # Initial transformation guess
reg_p2p = o3d.pipelines.registration.registration_icp(
    transformed_pcd1, pcd2, threshold, trans_init,
    o3d.pipelines.registration.TransformationEstimationPointToPoint()
)

# Get the transformation matrix
icp_transformation = reg_p2p.transformation
print("Transformation Matrix from ICP:\n", icp_transformation)

# Transform the source point cloud
transformed_pcd1.transform(icp_transformation)

print("Fitness:", reg_p2p.fitness)
print("Inlier RMSE:", reg_p2p.inlier_rmse)
# Visualize the aligned point clouds
bbox1 = transformed_pcd1.get_axis_aligned_bounding_box()
bbox1.color = (1, 0, 0)  # Red box
bbox2 = pcd2.get_axis_aligned_bounding_box()
bbox2.color = (0, 1, 0)  # Green box
o3d.visualization.draw_geometries([transformed_pcd1, bbox1, pcd2, bbox2], window_name="ICP with Bounding Boxes")
# Out:
# Transformation Matrix from ICP:
#  [[ 9.99774014e-01  1.00092747e-02  1.87546278e-02 -2.32007868e+01]
#  [-1.29358949e-02  9.86527686e-01  1.63082148e-01 -5.19680074e+01]
#  [-1.68696256e-02 -1.63287901e-01  9.86434223e-01  2.71356186e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Fitness: 0.9993049119555144
# Inlier RMSE: 5.210148889499557
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
visualizePointCloud(transformed_pcd1)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
def point_cloud_to_depth_image(pcd, intrinsics, image_shape):
    """
    Convert a point cloud back to a depth image.
    
    Args:
        pcd (o3d.geometry.PointCloud): The point cloud after ICP.
        intrinsics (dict): Camera intrinsics with keys: fx, fy, cx, cy.
        image_shape (tuple): The shape of the depth image (height, width).
        
    Returns:
        np.ndarray: The reconstructed depth image.
    """
    # Get the points from the point cloud
    points = np.asarray(pcd.points)
    
    # Project 3D points to 2D image plane (THESE ARE SWAPPED I KNOW)
    x_2d = (intrinsics['fy'] * points[:, 1] / points[:, 2]) + intrinsics['cy']
    y_2d = -1*(intrinsics['fx'] * points[:, 0] / points[:, 2]) + intrinsics['cx']
    
    # Round the coordinates to the nearest pixel (in case they are not integers)
    x_2d = np.round(x_2d).astype(int)
    y_2d = np.round(y_2d).astype(int)
    
    # Create an empty depth image with the given shape
    depth_img = np.zeros(image_shape)
    
    # Filter points that are within the image bounds
    valid_points = (x_2d >= 0) & (x_2d < image_shape[1]) & (y_2d >= 0) & (y_2d < image_shape[0])
    
    # Assign depth values to the corresponding pixels
    depth_img[y_2d[valid_points], x_2d[valid_points]] = points[valid_points, 2]
    
    return depth_img

# %%
#Extrinsic matrix = icp_transformation
def create_depth_image_from_point_cloud(point_cloud, intrinsics, img_shape):
    """
    Create a depth image from a point cloud using camera intrinsics.
    
    Args:
        point_cloud (open3d.geometry.PointCloud): The input point cloud.
        intrinsics (dict): Camera intrinsics with keys: fx, fy, cx, cy.
        img_shape (tuple): Shape of the output depth image (H, W).
    
    Returns:
        np.ndarray: Reconstructed depth image.
    """
    h, w = img_shape
    depth_img = np.zeros((h, w), dtype=np.float32)  # Initialize depth image with zeros
    rgb_img = np.zeros((h, w, 3), dtype=np.uint8)   # Initialize RGB image with zeros

    # Extract points from the point cloud
    points = np.asarray(point_cloud.points)  # Shape: (N, 3)
    colors = np.asarray(point_cloud.colors)  # Shape: (N, 3), values in [0, 1]

    y, x, z = points[:, 0], points[:, 1], points[:, 2]

    # Project 3D points back to 2D image plane
    i = (x * intrinsics['fy'] / z) + intrinsics['cy']
    j = (-y * intrinsics['fx'] / z) + intrinsics['cx']

    # Round to nearest integer and filter points that fall within the image boundaries
    i = np.round(i).astype(int)
    j = np.round(j).astype(int)
    valid = (i >= 0) & (i < w) & (j >= 0) & (j < h) & (z > 0)
    # i, j, z = i[valid], j[valid], z[valid]
    i, j, z, colors = i[valid], j[valid], z[valid], colors[valid]

    # Populate the depth image
    depth_img[j, i] = z
    rgb_img[j, i] = (colors * 255).astype(np.uint8)  # Scale to 0–255

    print(rgb_img.shape)
    return depth_img, rgb_img

# %%
img_width, img_height = 320, 240
fx = 583.2829786373293  # Focal length in x (example)
fy = 579.4112549695428  # Focal length in y (example)
cx = 320.0 /2  # Principal point x (example)
cy = 240.0/2 
img_shape = depth_img1.shape
intrinsic_array = np.array([
    [fx, 0, cx],  # Red
    [0, fy, cy],  # Green
    [0, 0, 0]   # Blue
])
# icp_depth = process_depth_and_rgb(intrinsic_array, pcd1, img_height, img_width)
icp_depth, icp_rgb = create_depth_image_from_point_cloud(pcd1, intrinsics, img_shape)
# vis_depth = icp_depth / np.max(icp_depth)
plt.imshow(icp_depth)



# c   = pcd1_copy.get_center()
# minb= pcd1_copy.get_min_bound()
# maxb= pcd1_copy.get_max_bound()
# print('point cloud center', c)
# print('min', minb)
# print('max', maxb)
# img_shape = depth_img1.shape
# icp_depth = create_depth_image_from_point_cloud(pcd1_copy, intrinsics, img_shape)

# plt.imshow(icp_depth)
# Out:
# (240, 320, 3)

# %% [markdown]
# #### Try to visualize depth cloud

# %%
# def process_depth_and_rgb(intrinsics_matrix, pcd, height_depth_image, width_depth_image):
#     # Matrix multiplication
    
    
#     points = np.asarray(pcd.points)  # Shape: (N, 3)
#     depth_img = np.zeros((height_depth_image, width_depth_image), dtype=np.float32)  # Initialize depth image with zeros

#     # #Into Pixel
#     # pixel_coords = np.dot(points, intrinsics_matrix)
  
#     # # Divide x, y by z to compute u, v
#     # v = np.round(pixel_coords[:, 0] / pixel_coords[:, 2]).astype(int)
#     # u = np.round(pixel_coords[:, 1] / pixel_coords[:, 2]).astype(int)
    
#     # Validate indices
#     valid_indexes = (u > 0) & (u <= height_depth_image) & (v > 0) & (v <= width_depth_image)
#     print("Number of valid indexes:", np.sum(valid_indexes))
    
#     # Filter valid indices
#     u_valid = u[valid_indexes]
#     v_valid = v[valid_indexes]
    
#     # Get all pixel depths and filter valid depths
#     # all_pixel_depths = pixel_coords[:, 1:3]
#     valid_depths = pixel_coords[valid_indexes, :]
    
#     # Initialize output images
#     pixel_depth_image = np.zeros((height_depth_image, width_depth_image))
    
#     # Store valid depth and RGB values
#     for i in range(len(valid_depths)):
#         pixel_depth_image[u_valid[i], v_valid[i]] = valid_depths[i, 0]
#         # pixel_rgb_image[u_valid[i], v_valid[i], :] = valid_depths[i, 1:3]
    
#     return pixel_depth_image

# %%
# def create_depth_image_from_point_cloud(point_cloud, intrinsics, img_shape):
#     """
#     Create a depth image from a point cloud using camera intrinsics.
    
#     Args:
#         point_cloud (open3d.geometry.PointCloud): The input point cloud.
#         intrinsics (dict): Camera intrinsics with keys: fx, fy, cx, cy.
#         img_shape (tuple): Shape of the output depth image (H, W).
    
#     Returns:
#         np.ndarray: Reconstructed depth image.
#     """
#     h, w = img_shape
#     depth_img = np.zeros((h, w), dtype=np.float32)  # Initialize depth image with zeros

#     # Extract points from the point cloud
#     points = np.asarray(point_cloud.points)  # Shape: (N, 3)
#     x, y, z = points[:, 0], points[:, 1], points[:, 2]

#     # Project 3D points back to 2D image plane
#     i = (x * intrinsics['fx'] / z) + intrinsics['cx']
#     j = (-y * intrinsics['fy'] / z) + intrinsics['cy']

#     # Round to nearest integer and filter points that fall within the image boundaries
#     i = np.round(i).astype(int)
#     j = np.round(j).astype(int)
#     valid = (i >= 0) & (i < w) & (j >= 0) & (j < h) & (z > 0)
#     i, j, z = i[valid], j[valid], z[valid]

#     # Populate the depth image
#     depth_img[j, i] = z

#     return depth_img

# %%
print(depth_img1.shape)
# Out:
# (240, 320)

# %%
# icp_depth = create_depth_image_from_point_cloud(transformed_pcd1, intrinsics, depth_img1.shape)
# plt.imshow(icp_depth)

# %% [markdown]
# ### Step 3d: Visualize Affine Transformation

# %% [markdown]
# TODO: Normalize the transformed image with depth to remove the artifacts from transformed PC
#
# Visually, that looks good! Let's plot the transformed image as a point cloud and the second image as apoint cloud, overlay them in the same space to verify.
#
# Add a convert the transformed point cloud back into depth

# %%
import copy

intrinsics = {
    'fx': 583.2829786373293,  # Focal length in x (example)
    'fy': 579.4112549695428,  # Focal length in y (example)
    'cx': 320.0,  # Principal point x (example)
    'cy': 240.0,  # Principal point y (example)
}

translated_img_depth_mask = copy.deepcopy(translated_img_depth)
mask = (translated_img_depth >= 1100) & (translated_img_depth <= 1800)

# Set pixels outside this range to 0
translated_img_depth_mask[~mask] = 0

# Create point clouds
translated_pcd1 = create_point_cloud_from_images(translated_img_colour, translated_img_depth_mask, intrinsics)

visualizePointCloud(translated_pcd1)
#Need to get the translated image colour to be transformed the same
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Normalize the depth images to the range [0, 1]
# translated_img_depth = (translated_img_depth - np.min(translated_img_depth)) / (np.max(translated_img_depth) - np.min(translated_img_depth))
# depth_img2 = (depth_img2 - np.min(depth_img2)) / (np.max(depth_img2) - np.min(depth_img2))

# Generate X, Y coordinates for the depth maps
x = np.arange(translated_img_depth.shape[1])
y = np.arange(translated_img_depth.shape[0])
x, y = np.meshgrid(x, y)

plt.figure(figsize=(10, 8))

# Plot the first depth image
plt.imshow(translated_img_depth, cmap='viridis', alpha=0.6, label="Depth Image 1")

# Overlay the second depth image
plt.imshow(depth_img2, cmap='cool', alpha=0.6, label="Depth Image 2")

# Add a colorbar

# Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Overlap of Two Depth Images (Top-Down View)")

plt.show()

# %% [markdown]
# Flaw: The translated image has a bunch of black pixels in it which is going to mess up the RGB image. This is a problem. Instead, take the pixels of the background wall in the original depth_image1 and map them to a new canvas then just put the trasnlated_depth image onto that canvas

# %% [markdown]
# #### TODO: Set the background depth pixels to zero as well

# %%
max(depth_img1[239])

#en(depth_img1)
# Out:
# 1311

# %% [markdown]
# ## Step 4: Remove the Background from RGB Images + Convert to HSV

# %% [markdown]
#  TODO: Try to remove the colour ranges of the background pixels

# %% [markdown]
# #### Remove Backgrounds

# %%
#Based on mins and maxs of depth image
# min_depth = 1380
# max_depth = 1700
min_depth = 1000
max_depth = 1400

# Mask the depth image
depth_mask = (translated_img_depth >= min_depth) & (translated_img_depth <= max_depth)
plt.imshow(depth_mask)

# Create a canvas with the same size as the depth image (black by default)
image1_cropped = np.zeros_like(translated_img_colour)

# Loop through the pixels of the color image and apply the depth mask
for y in range(translated_img_colour.shape[0]):
    for x in range(translated_img_colour.shape[1]):
        if depth_mask[y, x]:  # If depth is within the desired range
            image1_cropped[y, x] = translated_img_colour[y, x]  # Copy the color from the original image
        else:
            # image1_cropped[y, x] = (255, 255, 255)  # Set the pixel to black if outside the range
            image1_cropped[y, x] = (0, 0, 0)  # Set the pixel to black if outside the range

plt.imshow(image1_cropped)
#canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)

# %% [markdown]
# ##### For Point Cloud:

# %%
#Based on mins and maxs of depth image
# min_depth = 1380
# max_depth = 1700
min_depth = 1000
max_depth = 1400

# Mask the depth image
points = np.asarray(pcd1.points)  # Shape: (N, 3) where each row is (x, y, z)
colors = np.asarray(pcd1.colors) 

# Apply depth mask (filter points based on their z-values)
depth_mask = (points[:, 2] >= min_depth) & (points[:, 2] <= max_depth)
filtered_points = points[depth_mask]
filtered_colors = colors[depth_mask]

# Create a new Open3D PointCloud object with filtered points
image1_cropped_pc = o3d.geometry.PointCloud()
image1_cropped_pc.points = o3d.utility.Vector3dVector(filtered_points)
image1_cropped_pc.colors = o3d.utility.Vector3dVector(filtered_colors)

visualizePointCloud(image1_cropped_pc)
#canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
# import open3d as o3d
# import numpy as np
# import cv2

# # Load your point cloud (replace with your actual point cloud file or object)
# # Example: pcd1_copy = o3d.io.read_point_cloud("point_cloud.ply")
# # Assuming `pcd1_copy` is an Open3D PointCloud object

# # Convert PointCloud to NumPy arrays
# points = np.asarray(pcd1_copy.points)  # Shape: (N, 3) where each row is (x, y, z)
# colors = np.asarray(pcd1_copy.colors)  # Shape: (N, 3) where each row is (r, g, b)

# # Define depth range
# min_depth = 1000
# max_depth = 1400

# # Apply depth mask (filter points based on their z-values)
# depth_mask = (points[:, 2] >= min_depth) & (points[:, 2] <= max_depth)
# filtered_points = points[depth_mask]
# filtered_colors = colors[depth_mask]

# # Camera intrinsics (assume simple pinhole model, adjust as needed)
# fx, fy = 583.2829786373293, 579.4112549695428  # Focal lengths (in pixels)
# cx, cy = 120, 160  # Principal point (image center for a 640x480 image)
# image_width, image_height = 240, 320

# # Project points to 2D
# projected_points = np.zeros((image_height, image_width, 3), dtype=np.uint8)  # 3 channels for RGB

# for i in range(filtered_points.shape[0]):
#     x, y, z = filtered_points[i]
#     r, g, b = (filtered_colors[i] * 255).astype(np.uint8)  # Convert color to 0-255 range
    
#     # Perspective projection
#     u = int((fx * x / z) + cx)
#     v = int((fy * y / z) + cy)
    
#     # Ensure the point falls within the image bounds
#     if 0 <= u < image_width and 0 <= v < image_height:
#         projected_points[v, u] = [r, g, b]  # OpenCV uses BGR format

# # Save or display the 2D image
# plt.imshow(projected_points)

# %%
#Based on mins and maxs of depth image
# min_depth = 1380
# max_depth = 1700
min_depth = 1000
max_depth = 1400

# Mask the depth image
depth_mask = (depth_img2 >= min_depth) & (depth_img2 <= max_depth)

# Create a canvas with the same size as the depth image (black by default)
image2_cropped = np.zeros_like(colour_img2)

# Loop through the pixels of the color image and apply the depth mask
for y in range(colour_img2.shape[0]):
    for x in range(colour_img2.shape[1]):
        if depth_mask[y, x]:  # If depth is within the desired range
            image2_cropped[y, x] = colour_img2[y, x]  # Copy the color from the original image
        else:
            #image2_cropped[y, x] = (255, 255, 255)  # Set the pixel to black if outside the range
            image2_cropped[y, x] = (0, 0, 0)  # Set the pixel to black if outside the range


plt.imshow(image2_cropped)
#canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)

# %%
#Based on mins and maxs of depth image
# min_depth = 1380
# max_depth = 1700
min_depth = 1000
max_depth = 1400

# Mask the depth image
points = np.asarray(pcd2.points)  # Shape: (N, 3) where each row is (x, y, z)
colors = np.asarray(pcd2.colors) 

# Apply depth mask (filter points based on their z-values)
depth_mask = (points[:, 2] >= min_depth) & (points[:, 2] <= max_depth)
filtered_points = points[depth_mask]
filtered_colors = colors[depth_mask]

# Create a new Open3D PointCloud object with filtered points
image2_cropped_pc = o3d.geometry.PointCloud()
image2_cropped_pc.points = o3d.utility.Vector3dVector(filtered_points)
image2_cropped_pc.colors = o3d.utility.Vector3dVector(filtered_colors)

visualizePointCloud(image2_cropped_pc)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %% [markdown]
# Now I need the pixels where the masked image is non-black from the original colour image;

# %%
#Gte the pixels where neither is empty (more rigourous)
mask1 = np.all(image1_cropped != [0, 0, 0], axis=-1) 
mask2 = np.all(image2_cropped != [0, 0, 0], axis=-1)  # Non-black pixels in translated_img_colour

mask = (np.all(image1_cropped != [0, 0, 0], axis=-1)  & np.all(image2_cropped != [0, 0, 0], axis=-1) )
#mask = np.all(image2_cropped != [0, 0, 0], axis=-1)  # Non-black pixels in translated_img_colour

# Step 2: Create a copy of the canvas to overlay the image onto
h, w, channels = image1_cropped.shape
transformed_cropped = np.zeros((h, w, channels), dtype=np.uint8)

# Step 3: Use the mask to copy pixels from translated_img_colour to the canvas
transformed_cropped[mask] = translated_img_colour[mask]

# Step 4: Display the result
plt.imshow(transformed_cropped)
plt.show()

# %%
#Based on mins and maxs of depth image
# min_depth = 1380
# max_depth = 1700
min_depth = 1000
max_depth = 1400

# Mask the depth image
points = np.asarray(transformed_pcd1.points)  # Shape: (N, 3) where each row is (x, y, z)
colors = np.asarray(transformed_pcd1.colors) 

# Apply depth mask (filter points based on their z-values)
depth_mask = (points[:, 2] >= min_depth) & (points[:, 2] <= max_depth)
filtered_points = points[depth_mask]
filtered_colors = colors[depth_mask]

# Create a new Open3D PointCloud object with filtered points
transformed_cropped_pc = o3d.geometry.PointCloud()
transformed_cropped_pc.points = o3d.utility.Vector3dVector(filtered_points)
transformed_cropped_pc.colors = o3d.utility.Vector3dVector(filtered_colors)

visualizePointCloud(transformed_cropped_pc)
#canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %% [markdown]
# #### Convert RGB to HSV (unused)

# %%
hsvImg2 = cv2.cvtColor(image2_cropped, cv2.COLOR_RGB2HSV)
hsvImg1 = cv2.cvtColor(image1_cropped, cv2.COLOR_RGB2HSV)
hsvTransformed = cv2.cvtColor(transformed_cropped, cv2.COLOR_RGB2HSV)


# hsvImg2 = cv2.cvtColor(colour_img2, cv2.COLOR_RGB2HSV)
# hsvImg1 = cv2.cvtColor(colour_img2, cv2.COLOR_RGB2HSV)
# hsvTransformed = cv2.cvtColor(translated_img_colour, cv2.COLOR_RGB2HSV)
print(hsvImg.shape)
plt.imshow(hsvImg2[:,:,1], cmap='hot')
plt.colorbar()
# Out:
# (240, 320, 3)

# %%
# # alpha = 1 # Simple contrast control
# # beta = 1.5  # Simple brightness control - doesn't chnage saturation
# # hsvImg2_cp = np.zeros_like(hsvImg2)

# # for y in range(hsvImg2.shape[0]):
# #     for x in range(hsvImg2.shape[1]):
# #         for c in range(hsvImg2.shape[2]):
# #             hsvImg2_cp[y,x,c] = np.clip(alpha*hsvImg2[y,x,c] + beta, 0, 255)
# #             hsvImg2_cp[y,x,c] = np.clip(alpha*hsvImg2[y,x,c] + beta, 0, 255)


# hue, saturation, value = cv2.split(hsvImg2)

# # Normalize the saturation to stretch its range and increase contrast
# # saturation = cv2.normalize(saturation, None, 0, 255, cv2.NORM_MINMAX)

# # You can apply a nonlinear transformation (e.g., power law) to make the differences in saturation more visible
# gamma = 0.5  # You can adjust gamma to control the emphasis on differences
# saturation = np.power(saturation / 255.0, gamma) * 255.0
# saturation = np.uint8(saturation)

# # enhanced_hsv = cv2.merge([hue, saturation, value])

# plt.subplot(1,2,1)
# plt.imshow(hsvImg2[:,:,1])
# plt.subplot(1,2,2)
# plt.imshow(saturation)
# # plt.imshow(colour_img1)
# # plt.subplot(1,4,4)
# # plt.imshow(copy_colourImage1)

# %%
# #Based on mins and maxs of depth image
# # min_depth = 1380
# # max_depth = 1700
# min_depth = 1000
# max_depth = 1370

# channelImage = saturation
# # Mask the depth image
# depth_mask = (depth_img2 >= min_depth) & (depth_img2 <= max_depth)

# # Create a canvas with the same size as the depth image (black by default)
# hue_backgroundWhite = np.zeros_like(channelImage)
# print(hue_backgroundWhite.shape)
# # Loop through the pixels of the color image and apply the depth mask
# for y in range(channelImage.shape[0]):
#     for x in range(channelImage.shape[1]):
#         if depth_mask[y, x]:  # If depth is within the desired range
#             hue_backgroundWhite[y, x] = channelImage[y, x]  # Copy the color from the original image
#         else:
#             hue_backgroundWhite[y, x] = 255  # Set the pixel to black if outside the range
#             # hue_backgroundWhite[y, x] = 0  # Set the pixel to black if outside the range


# plt.imshow(hue_backgroundWhite, cmap='hot')
# #canvas[depth_mask] = colour_img1  # You can adjust this value for visualization (e.g., color or intensity)

# %% [markdown]
# #### For Point Clouds (unused in pipeline)
#
# TODO: Try both with the regular pcd2 and cropped_img2_pc

# %%
colors_transformed = np.asarray(image2_cropped_pc.colors)  # Shape: (M, 3)

# Scale RGB colors from [0, 1] to [0, 255] for cv2 compatibility
colors_trans_scaled = (colors_transformed * 255).astype(np.uint8)

# Convert RGB to HSV
hsv_colors_transformed = cv2.cvtColor(colors_trans_scaled.reshape(-1, 1, 3), cv2.COLOR_RGB2HSV).reshape(-1, 3)

# Optional: Scale back to [0, 1] if needed
hsv_colors1_normalized = hsv_colors_transformed.astype(np.float32) / 255.0

brightness_channel = hsv_colors1_normalized[:, 2]  # Extract brightness (V)

# # Replicate the brightness channel across three columns to create grayscale RGB
# grayscale_colors = np.stack([brightness_channel] * 3, axis=-1)
brightness_channel_normalized = (brightness_channel - brightness_channel.min()) / (brightness_channel.max() - brightness_channel.min())

# Apply the "hot" colormap
cmap = plt.get_cmap("ocean")
hot_colors = cmap(brightness_channel_normalized)[:, :3]  # Extract RGB values


# Replace point cloud colors with HSV values
hsv_pcd2_hot = o3d.geometry.PointCloud()
hsv_pcd2_hot.points = image2_cropped_pc.points  # Keep the original points
#Channel 1: Hue
#Channel 2: Saturation
#Channel 3: Brightness
hsv_pcd2_hot.colors = o3d.utility.Vector3dVector(hot_colors)  # Assign HSV colors

# Visualize HSV point clouds
visualizePointCloud(hsv_pcd2_hot)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %% [markdown]
# ## Step 5: Get the Difference between Transformed Image and Original Second Image (RBG)

# %% [markdown]
# #### Get the Differences

# %%
from PIL import Image, ImageChops

# convert to pillow
col_image1 = Image.fromarray(image1_cropped)
col_image2 = Image.fromarray(image2_cropped)
col_image3 = Image.fromarray(transformed_cropped)
# col_image1 = Image.fromarray(hsvImg1[:,:,1])
# col_image2 = Image.fromarray(hsvImg2[:,:,1])
# col_image3 = Image.fromarray(hsvTransformed[:,:,1])

diff_original = ImageChops.difference(col_image1, col_image2) 
diff_trans = ImageChops.difference(col_image2, col_image3) 
diff_og_trans = ImageChops.difference(col_image1, col_image3) 

diff_diff = ImageChops.difference(diff_original, diff_og_trans) 

# diff.show()
# plt.show()

plt.figure(figsize=(18, 6))

# Plot original image2
plt.subplot(2, 3, 1)
plt.title("Original Image 1")
plt.imshow(col_image1)

# Plot transformed image2
plt.subplot(2, 3, 2)
plt.title("Original Image 2")
plt.imshow(col_image2)

# Plot difference image
plt.subplot(2, 3, 3)
plt.title("Difference (btwn Originals)")
plt.imshow(diff_original)

plt.subplot(2, 3, 4)
plt.title("Transformed Image 2")
plt.imshow(col_image3)

plt.subplot(2, 3, 5)
plt.title("Difference Transformed vs Masked Original (Goal)")
plt.imshow(diff_trans)

plt.subplot(2, 3, 6)
plt.title("Difference Original unmasked vs transformed mask")
plt.imshow(diff_og_trans)

# Convert to grayscale (if not already)
diff_original = diff_original.convert("L")
# Convert the image to a NumPy array
diff_original_array = np.array(diff_original)
# Calculate the sum of pixel values
diff_original_array_sum = np.sum(diff_original_array)



# # Convert to grayscale (if not already)
# diff_og_trans = diff_og_trans.convert("L")
# # Convert the image to a NumPy array
# diff_og_trans_array = np.array(diff_og_trans)
# # Calculate the sum of pixel values
# diff_og_trans_array_sum = np.sum(diff_og_trans_array)


# print('Originals:', diff_original_array_sum)
# print('Difference Original unmasked vs transformed mask:', diff_og_trans_array_sum)

# %% [markdown]
# ##### For Point Cloud:

# %%
combined_pcd = transformed_pcd1 + pcd2

# Visualize
visualizePointCloud(combined_pcd)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
if pcd2.has_colors():
    print("Color data shape:", np.asarray(pcd2.colors).shape)
    print("First few color values:", np.asarray(pcd2.colors)[:5])
# Out:
# Color data shape: (8631, 3)
# First few color values: [[0.2        0.18039216 0.10588235]
#  [0.15686275 0.14901961 0.09803922]
#  [0.19215686 0.18039216 0.14509804]
#  [0.16470588 0.15294118 0.11764706]
#  [0.06666667 0.07058824 0.03921569]]

# %%
colors_trans = np.asarray(transformed_cropped_pc.colors)
colors_1 = np.asarray(image1_cropped_pc.colors)
colors_2 = np.asarray(hsv_pcd2_hot.colors)

thres = 0.2
# Set values less than 0.1 to 0
colors_trans[colors_trans < thres] = 0
colors_1[colors_1 < thres] = 0
colors_2[colors_2 < thres] = 0

# Update the point cloud's colors
transformed_cropped_pc.colors = o3d.utility.Vector3dVector(colors_trans)
image1_cropped_pc.colors = o3d.utility.Vector3dVector(colors_1)
image2_cropped_pc.colors = o3d.utility.Vector3dVector(colors_2)

visualizePointCloud(hsv_pcd2_hot)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
min_points = min(len(np.asarray(image1_cropped_pc.points)), len(np.asarray(hsv_pcd2_hot.points)),len(np.asarray(transformed_cropped_pc.points)) )

print(len(np.asarray(image1_cropped_pc.points)))
print(len(np.asarray(hsv_pcd2_hot.points)))
print(len(np.asarray(transformed_cropped_pc.points)))
# # Ensure both point clouds have the same number of pointsqqq
# assert len(pcd1.points) == len(pcd2.points), "Point clouds must have the same number of points."

# Extract point coordinates and colors
points1 = np.asarray(transformed_cropped_pc.points[:min_points])
points2 = np.asarray(hsv_pcd2_hot.points[:min_points])
colors1 = np.asarray(transformed_cropped_pc.colors[:min_points])
colors2 = np.asarray(hsv_pcd2_hot.colors[:min_points])

difference = np.abs(colors2 - colors1)
# difference = np.clip(colors2 - colors1, 0, 255).astype(np.uint8)
scaling_factor = 5  # You can adjust this factor to control the level of exaggeration
scaled_difference = np.clip(difference * scaling_factor, 0, 255).astype(np.uint8)

print(difference) #8631, 3

diff_pcd = o3d.geometry.PointCloud()
diff_pcd.points = o3d.utility.Vector3dVector(image2_cropped_pc.points)
diff_pcd.colors = o3d.utility.Vector3dVector(scaled_difference)
mean_diff = np.mean(difference, axis=0)  # Mean difference per channel
max_diff = np.max(difference, axis=0)    # Maximum difference per channel
print("Mean RGB difference:", mean_diff)
print("Max RGB difference:", max_diff)

visualizePointCloud(diff_pcd)
# Out:
# 8632
# 8631
# 8632
# [[0.         0.         0.21176471]
#  [0.21960784 0.25294118 0.        ]
#  [0.         0.         0.20392157]
#  ...
#  [0.25098039 0.22352941 0.20784314]
#  [0.         0.         0.27058824]
#  [0.         0.28235294 0.        ]]
# Mean RGB difference: [0.18968833 0.22777698 0.17993871]
# Max RGB difference: [1.         0.95294118 0.96862745]
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
colors = np.asarray(diff_pcd.colors)  # RGB values are in range [0, 1]
colors_rgb = (colors * 255).astype(np.uint8)  # Scale to [0, 255] for OpenCV

# Convert RGB to HSV
colors_hsv = cv2.cvtColor(colors_rgb.reshape(1, -1, 3), cv2.COLOR_RGB2HSV).reshape(-1, 3)

# Scale HSV values back to [0, 1] for Open3D
colors_hsv_normalized = colors_hsv / np.array([179, 255, 255], dtype=np.float32)

# Assign HSV colors back to the point cloud
diff_pcd.colors = o3d.utility.Vector3dVector(colors_hsv_normalized)

# Save or visualize the point cloud
visualizePointCloud(diff_pcd)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
# if not pcd.has_colors():
#     raise ValueError("Point cloud does not have colors!")

# # Extract RGB colors as a NumPy array
# colors = np.asarray(pcd.colors)  # RGB values are in range [0, 1]
# colors_rgb = (colors * 255).astype(np.uint8)  # Scale to [0, 255] for OpenCV

# # Convert RGB to HSV
# colors_hsv = cv2.cvtColor(colors_rgb.reshape(1, -1, 3), cv2.COLOR_RGB2HSV).reshape(-1, 3)

# # Scale HSV values back to [0, 1] for Open3D
# colors_hsv_normalized = colors_hsv a/ np.array([179, 255, 255], dtype=np.float32)

# # Assign HSV colors back to the point cloud
# pcd.colors = o3d.utility.Vector3dVector(colors_hsv_normalized)

# # Save or visualize the point cloud
# o3d.io.write_point_cloud("point_cloud_hsv.ply", pcd)
# o3d.visualization.draw_geometries([pcd])

# %%
# # Voxel size for discretization (adjust as necessary)
# voxel_size = 0.5

# # Create voxel grid filters for point clouds
# pcd1_voxel = transformed_pcd1.voxel_down_sample(voxel_size)
# pcd2_voxel = pcd2.voxel_down_sample(voxel_size)

# # Get the downsampled points and colors
# points1_voxel = np.asarray(pcd1_voxel.points[:min_points])
# points2_voxel = np.asarray(pcd2_voxel.points[:min_points])
# colors1_voxel = np.asarray(pcd1_voxel.colors[:min_points])
# colors2_voxel = np.asarray(pcd2_voxel.colors[:min_points])

# # Calculate voxel-wise RGB difference (Euclidean distance in RGB space)
# rgb_diff_voxel = np.linalg.norm(colors2_voxel - colors1_voxel, axis=1)

# # Normalize the RGB differences
# rgb_diff_normalized = np.clip(rgb_diff_voxel / np.max(rgb_diff_voxel), 0, 1)

# # Apply a colormap to visualize the difference
# # diff_colored = np.repeat(rgb_diff_normalized[:, np.newaxis], 3, axis=1)
# diff_colored = np.array([plt.cm.hot(val)[:3] for val in rgb_diff_normalized])

# # cmap = plt.get_cmap('hot')
# color_map = cmap(rgb_diff_normalized)[:, :3]

# # Create a new point cloud for voxel-wise differences
# diff_pcd = o3d.geometry.PointCloud()
# diff_pcd.points = o3d.utility.Vector3dVector(points2_voxel)
# diff_pcd.colors = o3d.utility.Vector3dVector(color_map)

# # Visualize the voxel-wise RGB difference
# visualizePointCloud(diff_pcd)
# # Optionally, save the result

# %%
# min_points = min(len(np.asarray(pcd1.points)), len(np.asarray(pcd2.points)),len(np.asarray(transformed_pcd1.points)) )

# image1_pc_colours = np.asarray(pcd1.colors)[:min_points]  # Shape: (N, 3)
# image2_pc_colours = np.asarray(pcd2.colors)[:min_points] 
# transformed_pc_colours = np.asarray(transformed_pcd1.colors)[:min_points] 

# assert np.all((0 <= image1_pc_colours) & (image1_pc_colours <= 1)), "Colors1 are not normalized"
# assert np.all((0 <= image2_pc_colours) & (image2_pc_colours <= 1)), "Colors2 are not normalized"
# assert np.all((0 <= transformed_pc_colours) & (transformed_pc_colours <= 1)), "Colors3 are not normalized"



# og_diff_pc = np.abs(image1_pc_colours - image2_pc_colours)  # Shape: (N, 3)
# diff_pc =  np.abs(image2_pc_colours - transformed_pc_colours)
# img1_trans_diff_pc = np.abs(image1_pc_colours - transformed_pc_colours)  # Shape: (N, 3)

# # rgb_diff_normalized = np.clip(diff_pc / np.max(diff_pc), 0, 1)  # Normalize to [0, 1]

# # # Apply a color map to the normalized difference
# # cmap = plt.get_cmap('hot')  # You can use 'jet', 'viridis', 'plasma', etc.
# # color_map = cmap(rgb_diff_normalized)[:, :3]  # Discard the alpha channel

# rgb_diff_normalized = np.clip(diff_pc * 255 / np.max(diff_pc), 0, 255)

# # Create a grayscale color map based on the difference
# diff_colored = np.repeat(rgb_diff_normalized[:, np.newaxis], 3, axis=1) / 255.0  # Normalize to [0, 1]


# # Create a new point cloud for the differences
# difference_pcd = o3d.geometry.PointCloud()

# difference_pcd.points = transformed_pcd1.points
# difference_pcd.colors = o3d.utility.Vector3dVector(diff_colored)

# # Visualize the point cloud showing RGB differences
# # Assign normalized differences as colors

# # # print(diff_pc.shape) #(8631, 3)
# # # Create a new point cloud to visualize the differences

# visualizePointCloud(difference_pcd)

# %% [markdown]
# #### Get the BRIGHTNESS channel of the DIFFERENCE image

# %%
diff = np.array(diff_trans)

hsvImg2_diff = cv2.cvtColor(diff, cv2.COLOR_RGB2HSV)
# hsvImg2 = cv2.cvtColor(colour_img2, cv2.COLOR_RGB2HSV)
# hsvImg1 = cv2.cvtColor(colour_img2, cv2.COLOR_RGB2HSV)
# hsvTransformed = cv2.cvtColor(translated_img_colour, cv2.COLOR_RGB2HSV)
print(hsvImg2_diff.shape)
plt.imshow(hsvImg2_diff[:,:,2], cmap='jet')
plt.colorbar()
# Out:
# (240, 320, 3)

# %% [markdown]
# ##### For Point Clouds

# %%
colors_transformed = np.asarray(diff_pcd.colors)  # Shape: (M, 3)

# Scale RGB colors from [0, 1] to [0, 255] for cv2 compatibility
colors_trans_scaled = (colors_transformed * 255).astype(np.uint8)

print(colors_trans_scaled.shape)
# Convert RGB to HSV
hsv_colors_transformed = cv2.cvtColor(colors_trans_scaled.reshape(-1, 1, 3), cv2.COLOR_BGR2HSV).reshape(-1, 3)

# Optional: Scale back to [0, 1] if needed
# hsv_colors1_normalized = hsv_colors_transformed.astype(np.float32) / 255.0

brightness_channel = hsv_colors_transformed[:, 0]  # Extract brightness (V)

brightness_normalized = brightness_channel / 255.0  # OpenCV scales to 0-255, we normalize to 0-1
hot_colors = plt.cm.jet(brightness_normalized)[:, :3]  # Use only RGB channels (not alpha)

# Create a new color array for the point cloud, where each point is assigned the brightness value
# output_colors = np.zeros_like(colors_trans_scaled)
# output_colors[:, 0] = 0  # Assign the brightness to the R channel
# output_colors[:, 1] = 0  # Assign the brightness to the G channel
# output_colors[:, 2] = brightness_normalized  # Assign the brightness to the B channel

# Replace point cloud colors with HSV values
hsv_pcd1 = o3d.geometry.PointCloud()
hsv_pcd1.points = diff_pcd.points  # Keep the original points
#Channel 1: Hue
#Channel 2: Saturation
#Channel 3: Brightness
hsv_pcd1.colors = o3d.utility.Vector3dVector(hot_colors)  # Assign HSV colors

# Visualize HSV point clouds
visualizePointCloud(hsv_pcd1)
# Out:
# (8631, 3)
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %% [markdown]
# ## Step 6: Clustering

# %% [markdown]
# diff_trans is the difference between the transformed and the masked images
#
# colour_image2 is the ORIGINAL masked image (RGB)
#
#
# cropped_image2 is the RGB masked image without a background
#
# hsvImg2 is the cropped (without a background) masked image, as a HSV
#
# hsvImg2[:,:,0] is the HUE image with a max of 179
# hsvImg2[:,:,1] is the Saturation channel, max 255
# hsvImg2[:,:,2] is the Value channel, max 255

# %% [markdown]
# Need the image as a NP array

# %% [markdown]
# #### Plot the HSV brightness image again

# %%
plt.imshow(hsvImg2_diff[:,:,2], cmap='hot')

# %% [markdown]
# ### Step 6a: K-means Clustering

# %%
image = hsvImg2_diff[:,:,2]

# Reshape and convert image to float32 for k-means
Z = image.reshape((-1, 1))
Z = np.float32(Z)

# Define k-means criteria and apply k-means - iterations, then epilson
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.2)
K = 2
_, label, center = cv2.kmeans(Z, K, None, criteria, attempts=20, flags=cv2.KMEANS_RANDOM_CENTERS)

# Convert cluster centers to uint8
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((image.shape))

# Create the plot
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Display the original and clustered images
ax[0].imshow(image, cmap='jet')
ax[0].set_title("Original Image")
ax[0].axis('off')

ax[1].imshow(res2, cmap='jet')
ax[1].set_title("Clustered Image")
ax[1].axis('off')

# Add a legend for the clusters
unique_clusters = np.arange(K)  # 0, 1, ..., K-1
colors = [plt.cm.jet(c / 255) for c in center.flatten()]  # Map grayscale to colors
legend_labels = [f"Cluster {i}" for i in unique_clusters]

# Create legend entries
legend_patches = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
    for color in colors
]
fig.legend(legend_patches, legend_labels, loc='upper right', title="Clusters")

plt.tight_layout()
plt.show()

# %%
visualizePointCloud(hsv_pcd1)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def kdtree(outlier_cloud):
    pcd_tree = o3d.geometry.KDTreeFlann(outlier_cloud)

    assigned = np.zeros(len(outlier_cloud.points), dtype=bool)
    labels = np.zeros(len(outlier_cloud.points), dtype=int)

    for i in range(len(outlier_cloud.points)):
        if assigned[i]:
            continue  # Skip already assigned points

        query_point = outlier_cloud.points[i]  # Query point
        [k, indices, _] = pcd_tree.search_knn_vector_3d(query_point, 2500)  # KNN search

        # Assign the current point and its neighbors to a cluster
        assigned[i] = True
        assigned[indices] = True

        cluster_label = i + 1  # Cluster label for this group
        labels[i] = cluster_label
        labels[indices] = cluster_label

    # Create the colormap
    unique_labels = np.unique(labels)
    num_clusters = len(unique_labels)
    cmap = cm.get_cmap('tab20', num_clusters)  # Using 'tab20' colormap for distinct colors
    print("Number Clusters:", num_clusters)
    colors = np.zeros((len(outlier_cloud.points), 3))  # Initialize colors array

    for cluster_label in unique_labels:
        cluster_indices = np.where(labels == cluster_label)[0]
        cluster_color = cmap(cluster_label / num_clusters)[:3]  # Normalize cluster label for color map
        colors[cluster_indices] = cluster_color  # Assign color to points in the cluster

    # Set colors for the point cloud
    outlier_cloud.colors = o3d.utility.Vector3dVector(colors)

    return outlier_cloud

# %%
def euclidean_distance(one_sample,X):
    #transfer one_sample into 1D vector
    one_sample = one_sample.reshape(1,-1)
    #transfer X into 1D vector
    X = X.reshape(X.shape[0],-1)
    #this is used to make sure one_sample's dimension is same as X
    distances = np.power(np.tile(one_sample,(X.shape[0],1))-X,2).sum(axis=1)
    return distances

# %%
class Kmeans():
    #constructor
    def __init__(self,k=2,max_iterations=1500,tolerance=0.00001):
        self.k = k
        self.max_iterations = max_iterations
        self.tolerance = tolerance
    
    #randomly select k centroids
    def init_random_centroids(self,X):
        #save the shape of X
        n_samples, n_features = np.shape(X)
        #make a zero matrix to store values
        centroids = np.zeros((self.k,n_features))
        #bcs there is k centroids, so we loop k tiems
        for i in range(self.k):
            #selecting values under the range radomly
            centroid = X[np.random.choice(range(n_samples))]
            centroids[i] = centroid
        return centroids

    #find the closest centroid of a sample
    def closest_centroid(self,sample,centroids):
        distances = euclidean_distance(sample,centroids)
        #np.argmin return the indices of the minimum of distances
        closest_i = np.argmin(distances)
        return closest_i

    #determine the clusers
    def create_clusters(self,centroids,X):
        n_samples = np.shape(X)[0]
        #This is to construct the nested list for storing clusters
        clusters = [[] for _ in range(self.k)]
        for sample_i, sample in enumerate(X):
            centroid_i = self.closest_centroid(sample,centroids)
            clusters[centroid_i].append(sample_i)
        return clusters

    #update the centroids based on mean algorithm
    def update_centroids(self,clusters,X):
        n_features = np.shape(X)[1]
        centroids = np.zeros((self.k,n_features))
        for i, cluster in enumerate(clusters):
            centroid = np.mean(X[cluster],axis=0)
            centroids[i] = centroid
        return centroids

    #obtain the labels
    #same cluster, same y_pred value
    def get_cluster_labels(self,clusters,X):
        y_pred = np.zeros(np.shape(X)[0])
        for cluster_i, cluster in enumerate(clusters):
            for sample_i in cluster:
                y_pred[sample_i] = cluster_i
        return y_pred

    #predict the labels
    def predict(self,X):
        #selecting the centroids randomly
        centroids = self.init_random_centroids(X)

        for _ in range(self.max_iterations):
            #clustering all the data point
            clusters = self.create_clusters(centroids,X)
            former_centroids = centroids
            #calculate new cluster center
            centroids = self.update_centroids(clusters,X)
            #judge the current difference if it meets convergence  
            diff = centroids - former_centroids
            if diff.any() < self.tolerance:
                break
            
        return self.get_cluster_labels(clusters,X)

# %%
def draw_labels_on_model(pcl,labels):
    cmap = plt.get_cmap("tab20")
    pcl_temp = copy.deepcopy(pcl)
    max_label = labels.max()
    colors = cmap(labels / (max_label if max_label > 0 else 1))
    pcl_temp.colors = o3d.utility.Vector3dVector(colors[:,:3])
    visualizePointCloud(pcl_temp)
    return pcl_temp

# %%
hsv_array = np.asarray(diff_pcd.points)

clf = Kmeans(k=15,max_iterations=1500,tolerance=0.000000001)
labels = clf.predict(hsv_array)

pcd_cluster_1 = draw_labels_on_model(diff_pcd,labels)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
visualizePointCloud(pcd_cluster_1)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
kdtree_pcd_copy = copy.deepcopy(diff_pcd)

clustered_pc = kdtree(kdtree_pcd_copy)
# Out:
# Number Clusters: 8
# /var/folders/9f/50_pwn910q9bx4yctj5dl_2c0000gn/T/ipykernel_6454/551981650.py:30: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', num_clusters)  # Using 'tab20' colormap for distinct colors

# %%
visualizePointCloud(clustered_pc)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
# from matplotlib.animation import FuncAnimation

# # Assuming 'point_cloud' is a numpy array of shape (N, 3) where N is the number of points
# # point_cloud = np.array([...])  # Replace with your point cloud data
# array_hsvImage1 = np.asarray(hsv_pcd1.points)
# print((array_hsvImage1.shape))
# # Reshape the point cloud to be a 2D array (N, 3), where each row is a point [x, y, z]
# Z = array_hsvImage1.reshape((-1, 3))  # Flatten the point cloud to 3 columns (x, y, z)

# # Convert to float32 for k-means
# Z = np.float32(Z)

# # Define k-means criteria and apply k-means
# criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 70, 2.5)
# K = 15  # Number of clusters
# _, label, center = cv2.kmeans(Z, K, None, criteria, attempts=20, flags=cv2.KMEANS_RANDOM_CENTERS)

# colors = np.random.rand(K, 3)  # Random colors for each cluster
# point_colors = colors[label.flatten()]  # Assign colors to each point based on its label

# # Set the point cloud colors
# hsv_pcd1.colors = o3d.utility.Vector3dVector(point_colors)  # Assign colors to the point cloud

# visualizePointCloud(hsv_pcd1)

# %% [markdown]
# ##### Plot the K-Means Clustering Results

# %%
fig, axes = plt.subplots(1, K + 1, figsize=(15, 5))


for cluster_to_plot in range(K):
    mask = (label.flatten() == cluster_to_plot).astype(np.uint8)  # Mask for current cluster
    single_cluster = mask.reshape(image.shape) * center[cluster_to_plot]  # Isolated cluster
    
    axes[cluster_to_plot + 1].imshow(single_cluster)
    axes[cluster_to_plot + 1].set_title(f"Cluster {cluster_to_plot}")
    axes[cluster_to_plot + 1].axis('off')

plt.tight_layout()
plt.show()

# %%
cluster_to_plot = 0  # Change this to the desired cluster index
mask = (label.flatten() == cluster_to_plot).astype(np.uint8)  # Create a mask for the cluster
single_cluster = mask.reshape(image.shape) * center[cluster_to_plot]  # Apply the mask

plt.imshow(single_cluster)

# %% [markdown]
# ## Step 7: Thresholding for Masking

# %% [markdown]
# #### Older Thresholding Attempts

# %%
# #HYPERPARAMETERS:
# binary_threshold_1 = 8 #How intense the original pixels must be to be kept
# kern_1 = (2,2) #Kernel to remove the thin edges (smaller kernel keeps smaller edges)
# conn_1 = 8 #tells us how many 'on' pixels each pixel must be touching to be kept - must be 4 or 8
# min_area_1 = 500 #The minimum areas that must be filled in to keep


# #RGB  HSv
# # Threshold the image to binary (adjust threshold as needed)
# # _, binary = cv2.threshold(diff_array, binary_threshold_1, 255, cv2.THRESH_BINARY)
# binary = cv2.adaptiveThreshold(single_cluster,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 35, 20)

# # First pass to remove thin edges
# kernel_1 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, kern_1)  # Small kernel
# cleaned_1 = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel_1)

# # Ensure the cleaned image is binary and of correct type
# cleaned_binary_1 = cleaned_1.astype(np.uint8)

# # Remove small connected components from the first pass
# num_labels_1, labels_1, stats_1, _ = cv2.connectedComponentsWithStats(cleaned_binary_1, connectivity=conn_1)

# filtered_1 = np.zeros_like(cleaned_binary_1)
# for i in range(1, num_labels_1):  # Skip background label 0
#     if stats_1[i, cv2.CC_STAT_AREA] >= min_area_1:
#         filtered_1[labels_1 == i] = 255

# plt.figure(figsize=(25, 15))
# plt.subplot(1, 5, 1)
# plt.title('Original Grayscale')
# plt.imshow(single_cluster, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 2)
# plt.title('Adaptive Thresholding')
# plt.imshow(binary, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 3)
# plt.title('Morphological ')
# plt.imshow(filtered_1, cmap='gray')
# plt.axis('off')

# %% [markdown]
# ##### Try Adapative Thresholding (Sucks)

# %%
# diff_trans_array = np.array(diff_trans)
# print(type(diff_trans_array[0]))

# cv2.cvtColor(diff_trans_array, cv2.COLOR_BGR2HSV)

# plt.imshow(diff_trans_array)

# %%
# max_value = np.max(diff_trans)
# print(f"Maximum value in the HSV image: {max_value}")

# # If you want the maximum value per channel:
# h, s, v = cv2.split(hsvImg2)
# max_hue = np.max(h)          # Max in Hue channel
# max_saturation = np.max(s)   # Max in Saturation channel
# max_value_channel = np.max(v) # Max in Value channel

# print(max_hue)
# print(max_saturation)
# print(max_value_channel)

# %%
# #Try to run on the Original Masked Image
# #Original = colour_img2
# #HSV original - hsvImg2
# #Each channel of HSV original

# adapted = cv2.adaptiveThreshold(single_cluster, maxValue=255, adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C, thresholdType=cv2.THRESH_BINARY, blockSize=3, C=1)

# plt.imshow(adapted)

# %%
# # # Example: Compute the difference
# # diff_og_trans = ImageChops.difference(col_image2, col_image3) 
# # diff_array = np.array(diff_og_trans)

# # # Convert the difference to 8-bit grayscale
# # # diff_array = cv2.cvtColor(diff_array, cv2.COLOR_BGR2GRAY)  # If needed
# # diff_array = diff_array.astype(np.uint8)

# # Apply thresholds
# ret, th1 = cv2.threshold(single_cluster, 50, 255, cv2.THRESH_BINARY)
# th2 = cv2.adaptiveThreshold(single_cluster, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 33, 5)
# th3 = cv2.adaptiveThreshold(single_cluster, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
#                             cv2.THRESH_BINARY, 11, 1)

# # Visualization
# titles = ['Original Image', 'Global Thresholding (v = 55)',
#           'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
# images = [single_cluster, th1, th2, th3]

# for i in range(4):
#     plt.subplot(2, 2, i + 1)
#     plt.imshow(images[i], 'gray')
#     plt.title(titles[i])
#     plt.xticks([]), plt.yticks([])
# plt.show()

# %%
# # diff_og_trans = ImageChops.difference(col_image2, col_image3) 
# # diff_array = np.array(diff_og_trans)

# # print(max(diff_array.any))
# # Define a threshold value (e.g., 50)
# #threshold = 40
# kernel = np.ones((3, 3), np.uint8)
# # kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
# # closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

# closed_edges = cv2.morphologyEx(single_cluster, cv2.MORPH_CLOSE, kernel)

# # sharpened = cv2.filter2D(closed_edges, -1, kernel) # applying the sharpening kernel to the input image & displaying it.

# # # Apply the threshold: Set all values below the threshold to 0
# # #thresholded_diff = np.where(diff_array > threshold, diff_array, 0)

# # # Convert the thresholded result back to an image
# # thresholded_image = Image.fromarray(closed_edges.astype(np.uint8))

# # # Display or save the thresholded image
# # plt.figure(figsize=(18, 6))

# # Plot original image2
# plt.subplot(1, 2, 1)
# plt.title("Original Open ")
# plt.imshow(closed_edges)

# # # Plot transformed image2
# # plt.subplot(1, 2, 2)
# # plt.title("Sharpened")
# # plt.imshow(sharpened)

# %%
# import scipy.ndimage as nd
# from skimage.feature import canny

# # # Assuming col_image1 and col_image3 are PIL images
# # diff_og_trans = ImageChops.difference(col_image2, col_image3) 
# # diff = np.array(diff_og_trans)
# # diff = cv2.cvtColor(diff_array, cv2.COLOR_RGB2GRAY)
 
# # apply edge segmentation
# # plot canny edge detection
# edges = canny(single_cluster)

# fill_im = nd.binary_fill_holes(single_cluster - 1)
# plt.imshow(fill_im)
# plt.title('Region Filling')

# %%
# # Assuming col_image1 and col_image3 are PIL images
# diff_og_trans = ImageChops.difference(col_image2, col_image3) 
# diff_array = np.array(diff_og_trans)

# # Ensure the image is grayscale (single channel)
# if len(diff_array.shape) == 3:  # Multi-channel image
#     diff_array = cv2.cvtColor(diff_array, cv2.COLOR_BGR2GRAY)


# #HYPERPARAMETERS:
# binary_threshold_1 = 15 #How intense the original pixels must be to be kept
# kern_1 = (1, 1) #Kernel to remove the thin edges (smaller kernel keeps smaller edges)
# conn_1 = 8 #tells us how many 'on' pixels each pixel must be touching to be kept - must be 4 or 8
# min_area_1 = 200 #The minimum areas that must be filled in to keep


# kern_2 = (3,3) #Kernel to remove the thin edges (smaller kernel keeps smaller edges) - second pass
# conn_2 = 8 #tells us how many 'on' pixels each pixel must be touching to be kept - must be 4 or 8
# conn_3 = 8 #tells us how many 'on' pixels each pixel must be touching to be kept - must be 4 or 8
# min_area_2 = 600  # Slightly larger threshold for second pass
# binary_threshold_2 = 120 #How intense the  pixels must be to be kept
# min_area_3 = 850  # Slightly larger threshold for second pass
# kern_3 = (7,7)
# #RGB  HSv
# # Threshold the image to binary (adjust threshold as needed)
# # _, binary = cv2.threshold(diff_array, binary_threshold_1, 255, cv2.THRESH_BINARY)
# binary = cv2.adaptiveThreshold(diff_array, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 1)

# # First pass to remove thin edges
# kernel_1 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, kern_1)  # Small kernel
# cleaned_1 = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel_1)

# # Ensure the cleaned image is binary and of correct type
# cleaned_binary_1 = cleaned_1.astype(np.uint8)

# # Remove small connected components from the first pass
# num_labels_1, labels_1, stats_1, _ = cv2.connectedComponentsWithStats(cleaned_binary_1, connectivity=conn_1)

# filtered_1 = np.zeros_like(cleaned_binary_1)
# for i in range(1, num_labels_1):  # Skip background label 0
#     if stats_1[i, cv2.CC_STAT_AREA] >= min_area_1:
#         filtered_1[labels_1 == i] = 255


# # Second pass to remove remaining edges or artifacts
# kernel_2 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, kern_2)  # Slightly larger kernel
# cleaned_2 = cv2.morphologyEx(filtered_1, cv2.MORPH_CLOSE, kernel_2)

# # Remove small connected components again
# num_labels_2, labels_2, stats_2, _ = cv2.connectedComponentsWithStats(cleaned_2, connectivity=conn_2)
# #min_area_2 = 800  # Slightly larger threshold for second pass
# filtered_2 = np.zeros_like(cleaned_2)
# for i in range(1, num_labels_2):  # Skip background label 0
#     if stats_2[i, cv2.CC_STAT_AREA] >= min_area_2:
#         filtered_2[labels_2 == i] = 255


# _, binary2 = cv2.threshold(filtered_1, binary_threshold_2, 255, cv2.THRESH_BINARY)
# kernel_3 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, kern_3)  # Small kernel

# cleaned_3 = cv2.morphologyEx(filtered_2, cv2.MORPH_CLOSE, kernel_3)

# # Remove small connected components again
# num_labels_3, labels_3, stats_3, _ = cv2.connectedComponentsWithStats(cleaned_3, connectivity=conn_3)
# filtered_3 = np.zeros_like(cleaned_3)
# for i in range(1, num_labels_3):  # Skip background label 0
#     if stats_3[i, cv2.CC_STAT_AREA] >= min_area_3:
#         filtered_3[labels_3 == i] = 255
# # Visualize results

# plt.figure(figsize=(15, 5))
# plt.subplot(1, 5, 1)
# plt.title('Original Grayscale')
# plt.imshow(diff_array, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 2)
# plt.title('Binary Threshold')
# plt.imshow(binary, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 3)
# plt.title('After First Pass')
# plt.imshow(filtered_1, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 4)
# plt.title('After Second Pass')
# plt.imshow(filtered_2, cmap='gray')
# plt.axis('off')

# plt.subplot(1, 5, 5)
# plt.title('After Third Pass')
# plt.imshow(filtered_3, cmap='gray')
# plt.axis('off')

# plt.show()

# %% [markdown]
# ### Step 7a: Fill In Masked Area - Use Morphological Thresholding

# %%
kernel = np.ones((3, 3), np.uint8)

closed_edges = cv2.morphologyEx(single_cluster, cv2.MORPH_CLOSE, kernel)

plt.imshow(closed_edges)

# %% [markdown]
# ### Step 7b: Denoise the Filled in Mask

# %%
single_cluster_RGB = cv2.cvtColor(closed_edges, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR
closed_edges_ary = np.array(single_cluster_RGB)  # Ensure it's in a NumPy array format
dst = cv2.fastNlMeansDenoisingColored(closed_edges_ary, None, h=12, hColor=10, templateWindowSize=100, searchWindowSize=50)

# Display the denoised image
plt.imshow(dst)

# %% [markdown]
# ### Step 7c: Perform Median Blurring on Denoised Image

# %%
img_gray_blur = cv2.medianBlur(dst, 3) #THIS ONE


plt.imshow(img_gray_blur)

# %% [markdown]
# ## Step 8: Project Mask onto Occluded Image

# %%
rbg_nonoccluded = np.array(col_image2) # col_image1 is the NON-OCCLUDED original image
rbg_nonoccluded[img_gray_blur == 0] = 0
plt.imshow(rbg_nonoccluded)
plt.axis('off')
# Out:
# (-0.5, 319.5, 239.5, -0.5)

# %%
visualizePointCloud(diff_pcd)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
# (black by default)

# %%
# get region where mask is from non-occluded image

rbg_nonoccluded = np.array(col_image1) # col_image1 is the NON-OCCLUDED original image
rbg_nonoccluded[img_gray_blur == 0] = 0
plt.imshow(rbg_nonoccluded)
plt.axis('off')
# Out:
# (-0.5, 319.5, 239.5, -0.5)

# %%
visualizePointCloud(translated_pcd1)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
import open3d as o3d
import numpy as np

hsv_array = np.asarray(pcd_cluster_1.points)

# Get the minimum size between the two point clouds
min_size = min(len(np.asarray(pcd1.points)), len(np.asarray(pcd_cluster_1.points)))

# Extract points and colors from both point clouds
transformed_points = np.asarray(pcd1.points)[:min_size]
transformed_colors = np.asarray(pcd1.colors)[:min_size]

# Initialize the color array (black by default)
colors = np.zeros((min_size, 3))  # Black for all points

# Specify the cluster label you want to extract (e.g., label 7)
cluster_label = 1
labels_parsed = labels[:min_size]
# Apply bright red color to the points belonging to the specified cluster
# colors[labels_parsed == cluster_label] = [1, 0, 0]  # RGB for bright red

# Apply the RGB values from the second point cloud to the red points
colors[labels_parsed == cluster_label] = transformed_colors[labels_parsed == cluster_label]

# Create a new PointCloud object with the same points
colored_pcd = o3d.geometry.PointCloud()
colored_pcd.points = o3d.utility.Vector3dVector(hsv_array[:min_size])

# Assign the updated color array to the point cloud
colored_pcd.colors = o3d.utility.Vector3dVector(colors)

# Visualize the result
visualizePointCloud(colored_pcd)
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Closing the window
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized

# %%
# place the above region on the occluded image

face_seg = rbg_nonoccluded 
mask = np.any(face_seg > 0, axis=-1)
# rbg_mask = np.array(col_image2) # col_image3 is the occluded image!!

rbg_mask = np.array(colour_img2) # col_image3 is the occluded image!!

rbg_mask[mask] = face_seg[mask] # 

plt.imshow(rbg_mask)
plt.axis('off')

# plt.imshow(col_imag e2)
# Out:
# (-0.5, 319.5, 239.5, -0.5)
